# %% [markdown]
# ### 散点图

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
N = 1000
x = np.random.randn(N)
y = np.random.randn(N)
# 用matplotlib画图
plt.scatter(x, y, marker='x')
plt.show()
# 用Seaborn
df = pd.DataFrame({'x':x, 'y':y})
sns.jointplot(x, y, kind='scatter')
plt.show()
# Out:
# D:\Anaconda\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# ### 折线图

# %% [markdown]
# > 折线图可以用来表示数据随着时间变化的趋势

# %%
x = [2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019]
y = [5, 3, 6, 20, 17, 16, 19, 30, 32, 35]
plt.plot(x, y)
plt.show()
df = pd.DataFrame({'x':x, 'y':y})
sns.lineplot(x="x", y="y", data=df)
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# ### 直方图

# %%
a = np.random.randn(1000)
s = pd.Series(a)
plt.hist(s)
plt.show()
# kde 代表显示核密度估计，默认是 True
sns.distplot(s, kde=False)
plt.show()
sns.distplot(s, kde=True)
plt.show()

# %% [markdown]
# ### 条形图

# %%
x = ['Cat1', 'Cat2', 'Cat3', 'Cat4', 'Cat5']
y = [5, 4, 8, 12, 7]
plt.bar(x, y)
plt.show()
sns.barplot(x, y)
plt.show()

# %% [markdown]
# ### 箱线图

# %%
# 生成0-1之间的10*4维度数据
data = np.random.normal(size=(10, 4))
labels = ['A', 'B', 'C', 'D']
plt.boxplot(data, labels=labels)
plt.show()
df = pd.DataFrame(data, columns=labels)
sns.boxplot(data=df)
plt.show()

# %% [markdown]
# ### 饼图

# %%
# 数据准备
nums = [25, 37, 33, 37, 6]
labels = ['High-school','Bachelor','Master','Ph.d', 'Others']
plt.pie(x= nums, labels=labels)
plt.show()

# %% [markdown]
# ### 热力图

# %% [markdown]
# >是一种矩阵表示方法，其中矩阵中的元素值用颜色来代表，不同的颜色代表不同大小的值。通过颜色就能直观地知道某个位置上数值的大小。另外你也可以将这个位置上的颜色，与数据集中的其他位置颜色进行比较。

# %%
# 数据准备,记录了 1949 年到 1960 年期间，每个月的航班乘客的数量。
flights = sns.load_dataset("flights")
data=flights.pivot('year','month','passengers')
# 用Seaborn画热力图
sns.heatmap(data)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-28-e0fffd0bda18> in <module>()
#       4 import seaborn as sns
#       5 # 数据准备
# ----> 6 flights = sns.load_dataset("flights")
#       7 data=flights.pivot('year','month','passengers')
#       8 # 用Seaborn画热力图
#
# D:\Anaconda\lib\site-packages\seaborn\utils.py in load_dataset(name, cache, data_home, **kws)
#     426                                   os.path.basename(full_path))
#     427         if not os.path.exists(cache_path):
# --> 428             urlretrieve(full_path, cache_path)
#     429         full_path = cache_path
#     430
#
# D:\Anaconda\lib\urllib.pyc in urlretrieve(url, filename, reporthook, data, context)
#      96     else:
#      97         opener = _urlopener
# ---> 98     return opener.retrieve(url, filename, reporthook, data)
#      99 def urlcleanup():
#     100     if _urlopener:
#
# D:\Anaconda\lib\urllib.pyc in retrieve(self, url, filename, reporthook, data)
#     243             except IOError:
#     244                 pass
# --> 245         fp = self.open(url, data)
#     246         try:
#     247             headers = fp.info()
#
# D:\Anaconda\lib\urllib.pyc in open(self, fullurl, data)
#     211         try:
#     212             if data is None:
# --> 213                 return getattr(self, name)(url)
#     214             else:
#     215                 return getattr(self, name)(url, data)
#
# D:\Anaconda\lib\urllib.pyc in open_https(self, url, data)
#     441             if realhost: h.putheader('Host', realhost)
#     442             for args in self.addheaders: h.putheader(*args)
# --> 443             h.endheaders(data)
#     444             errcode, errmsg, headers = h.getreply()
#     445             fp = h.getfile()
#
# D:\Anaconda\lib\httplib.pyc in endheaders(self, message_body)
#    1036         else:
#    1037             raise CannotSendHeader()
# -> 1038         self._send_output(message_body)
#    1039
#    1040     def request(self, method, url, body=None, headers={}):
#
# D:\Anaconda\lib\httplib.pyc in _send_output(self, message_body)
#     880             msg += message_body
#     881             message_body = None
# --> 882         self.send(msg)
#     883         if message_body is not None:
#     884             #message_body was not a string (i.e. it is a file) and
#
# D:\Anaconda\lib\httplib.pyc in send(self, data)
#     842         if self.sock is None:
#     843             if self.auto_open:
# --> 844                 self.connect()
#     845             else:
#     846                 raise NotConnected()
#
# D:\Anaconda\lib\httplib.pyc in connect(self)
#    1253             "Connect to a host on a given (SSL) port."
#    1254
# -> 1255             HTTPConnection.connect(self)
#    1256
#    1257             if self._tunnel_host:
#
# D:\Anaconda\lib\httplib.pyc in connect(self)
#     819         """Connect to the host and port specified in __init__."""
#     820         self.sock = self._create_connection((self.host,self.port),
# --> 821                                            self.timeout, self.source_address)
#     822
#     823         if self._tunnel_host:
#
# D:\Anaconda\lib\socket.pyc in create_connection(address, timeout, source_address)
#     573
#     574     if err is not None:
# --> 575         raise err
#     576     else:
#     577         raise error("getaddrinfo returns an empty list")
#
# IOError: [Errno socket error] [Errno 10060]

# %% [markdown]
# ### 蜘蛛图

# %%
from matplotlib.font_manager import FontProperties  
labels=np.array([u"推进","KDA",u"生存",u"团战",u"发育",u"输出"])
stats=[83, 61, 95, 67, 76, 88]
angles = np.linspace(0, 2*np.pi, len(labels), endpoint=False)
fig = plt.figure()
ax = fig.add_subplot(111, polar=True)
ax.plot(angles, stats, 'o-', linewidth=2)
ax.fill(angles, stats, alpha=0.25)
# 设置中文字体
font = FontProperties(fname=r"C:\Windows\Fonts\simhei.ttf", size=14) 
ax.set_thetagrids(angles * 180 / np.pi, labels, FontProperties=font)
plt.show()

# %% [markdown]
# ### 二元变量分布

# %% [markdown]
# >sns.jointplot(x, y, data=None, kind) 函数即可。其中用 kind 表示不同的视图类型：“kind=‘scatter’”代表散点图，“kind=‘kde’”代表核密度图，“kind=‘hex’ ”代表 Hexbin 图，它代表的是直方图的二维模拟。

# %%
# 数据准备
tips = sns.load_dataset("tips")
print(tips.head(10))
# 用Seaborn画二元变量分布图（散点图，核密度图，Hexbin图）
sns.jointplot(x="total_bill", y="tip", data=tips, kind='scatter')
sns.jointplot(x="total_bill", y="tip", data=tips, kind='kde')
sns.jointplot(x="total_bill", y="tip", data=tips, kind='hex')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-32-e19bf353c83c> in <module>()
#       1 # 数据准备
# ----> 2 tips = sns.load_dataset("tips")
#       3 print(tips.head(10))
#       4 # 用Seaborn画二元变量分布图（散点图，核密度图，Hexbin图）
#       5 sns.jointplot(x="total_bill", y="tip", data=tips, kind='scatter')
#
# D:\Anaconda\lib\site-packages\seaborn\utils.py in load_dataset(name, cache, data_home, **kws)
#     426                                   os.path.basename(full_path))
#     427         if not os.path.exists(cache_path):
# --> 428             urlretrieve(full_path, cache_path)
#     429         full_path = cache_path
#     430
#
# D:\Anaconda\lib\urllib.pyc in urlretrieve(url, filename, reporthook, data, context)
#      96     else:
#      97         opener = _urlopener
# ---> 98     return opener.retrieve(url, filename, reporthook, data)
#      99 def urlcleanup():
#     100     if _urlopener:
#
# D:\Anaconda\lib\urllib.pyc in retrieve(self, url, filename, reporthook, data)
#     243             except IOError:
#     244                 pass
# --> 245         fp = self.open(url, data)
#     246         try:
#     247             headers = fp.info()
#
# D:\Anaconda\lib\urllib.pyc in open(self, fullurl, data)
#     211         try:
#     212             if data is None:
# --> 213                 return getattr(self, name)(url)
#     214             else:
#     215                 return getattr(self, name)(url, data)
#
# D:\Anaconda\lib\urllib.pyc in open_https(self, url, data)
#     441             if realhost: h.putheader('Host', realhost)
#     442             for args in self.addheaders: h.putheader(*args)
# --> 443             h.endheaders(data)
#     444             errcode, errmsg, headers = h.getreply()
#     445             fp = h.getfile()
#
# D:\Anaconda\lib\httplib.pyc in endheaders(self, message_body)
#    1036         else:
#    1037             raise CannotSendHeader()
# -> 1038         self._send_output(message_body)
#    1039
#    1040     def request(self, method, url, body=None, headers={}):
#
# D:\Anaconda\lib\httplib.pyc in _send_output(self, message_body)
#     880             msg += message_body
#     881             message_body = None
# --> 882         self.send(msg)
#     883         if message_body is not None:
#     884             #message_body was not a string (i.e. it is a file) and
#
# D:\Anaconda\lib\httplib.pyc in send(self, data)
#     842         if self.sock is None:
#     843             if self.auto_open:
# --> 844                 self.connect()
#     845             else:
#     846                 raise NotConnected()
#
# D:\Anaconda\lib\httplib.pyc in connect(self)
#    1253             "Connect to a host on a given (SSL) port."
#    1254
# -> 1255             HTTPConnection.connect(self)
#    1256
#    1257             if self._tunnel_host:
#
# D:\Anaconda\lib\httplib.pyc in connect(self)
#     819         """Connect to the host and port specified in __init__."""
#     820         self.sock = self._create_connection((self.host,self.port),
# --> 821                                            self.timeout, self.source_address)
#     822
#     823         if self._tunnel_host:
#
# D:\Anaconda\lib\socket.pyc in create_connection(address, timeout, source_address)
#     573
#     574     if err is not None:
# --> 575         raise err
#     576     else:
#     577         raise error("getaddrinfo returns an empty list")
#
# IOError: [Errno socket error] [Errno 10060]

# %% [markdown]
# ### 成对关系

# %%
url = "https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data"  
names = ['sepal-length', 'sepal-width', 'petal-length', 'petal-width', 'class']  
iris = pd.read_csv(url, names=names)
sns.pairplot(iris)
plt.show()
